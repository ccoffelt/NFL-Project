# %%
import pandas as pd
import numpy as np
import linearmodels as lm
import statsmodels.formula.api as smf

# %%
file_path = '/Users/austincoffelt/NFL-Project'

# %%
# Read in Data
dfNFL = pd.read_csv(f'{file_path}/data/nfl_drive.csv')
dfNFL = dfNFL.drop('Unnamed: 0', axis = 1)
dfNFL.head(50)
# Out:
# /var/folders/6z/0pv81j2524v8c80qsmnrbmcm0000gn/T/ipykernel_1898/1006253184.py:2: DtypeWarning: Columns (37,38,43,45,46,179,180,182,183,189,190,191,192,197,198,199,200,203,204,205,206,207,208,209,210,211,212,213,214,218,219,220,222,224,226,233,234,235,236,237,238,248,249,253,254,255,260,262,263,266,267,268,269,283,284,292,293,294,295,296,299,301,302,303,306,373,375,376,377,379,381,382,383,388,389,390,391,392,393,394,395,396,397) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfNFL = pd.read_csv(f'{file_path}/data/nfl_drive.csv')
#     play_id          game_id   old_game_id home_team away_team season_type  \
# 0      35.0  1999_01_ARI_PHI  1.999091e+09       PHI       ARI         REG
# 1     176.0  1999_01_ARI_PHI  1.999091e+09       PHI       ARI         REG
# 2     260.0  1999_01_ARI_PHI  1.999091e+09       PHI       ARI         REG
# 3     433.0  1999_01_ARI_PHI  1.999091e+09       PHI       ARI         REG
# ...

# %%
# get dummies for results
drive_results = pd.get_dummies(dfNFL['end_of_previous_drive'], drop_first=False)
dfNFL = pd.concat([dfNFL, drive_results], axis = 1)
dfNFL.head(50)
# Out:
#     play_id          game_id   old_game_id home_team away_team season_type  \
# 0      35.0  1999_01_ARI_PHI  1.999091e+09       PHI       ARI         REG
# 1     176.0  1999_01_ARI_PHI  1.999091e+09       PHI       ARI         REG
# 2     260.0  1999_01_ARI_PHI  1.999091e+09       PHI       ARI         REG
# 3     433.0  1999_01_ARI_PHI  1.999091e+09       PHI       ARI         REG
# 4     581.0  1999_01_ARI_PHI  1.999091e+09       PHI       ARI         REG
# 5     672.0  1999_01_ARI_PHI  1.999091e+09       PHI       ARI         REG
# 6     779.0  1999_01_ARI_PHI  1.999091e+09       PHI       ARI         REG
# 7     940.0  1999_01_ARI_PHI  1.999091e+09       PHI       ARI         REG
# 8     967.0  1999_01_ARI_PHI  1.999091e+09       PHI       ARI         REG
# 9    1037.0  1999_01_ARI_PHI  1.999091e+09       PHI       ARI         REG
# 10   1133.0  1999_01_ARI_PHI  1.999091e+09       PHI       ARI         REG
# ...

# %%
list(dfNFL.columns)
# Out:
# ['play_id',
#  'game_id',
#  'old_game_id',
#  'home_team',
#  'away_team',
#  'season_type',
#  'week',
#  'posteam',
#  'posteam_type',
#  'defteam',
#  'side_of_field',
#  'yardline_100',
#  'game_date',
#  'quarter_seconds_remaining',
#  'half_seconds_remaining',
#  'game_seconds_remaining',
#  'game_half',
#  'quarter_end',
#  'drive',
#  'sp',
#  'qtr',
#  'down',
#  'goal_to_go',
#  'time',
#  'yrdln',
#  'ydstogo',
#  'ydsnet',
#  'desc',
#  'play_type',
#  'yards_gained',
#  'shotgun',
#  'no_huddle',
#  'qb_dropback',
#  'qb_kneel',
#  'qb_spike',
#  'qb_scramble',
#  'pass_length',
#  'pass_location',
#  'air_yards',
#  'yards_after_catch',
#  'run_location',
#  'run_gap',
#  'field_goal_result',
#  'kick_distance',
#  'extra_point_result',
#  'two_point_conv_result',
#  'home_timeouts_remaining',
#  'away_timeouts_remaining',
#  'timeout',
#  'timeout_team',
#  'td_team',
#  'td_player_name',
#  'td_player_id',
#  'posteam_timeouts_remaining',
# ...

# %% [markdown]
# ## Passing Rate Analysis

# %%
# determine treatment
dfNFL['treated'] = 0 
dfNFL.loc[(dfNFL['quarter'] == 4) & (dfNFL['Touchdown'] == 1) & (dfNFL['quarter'] == 4)
